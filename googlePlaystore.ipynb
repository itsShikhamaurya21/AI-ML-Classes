# %%
import pandas as pd

# %%
df=pd.read_csv("googleplaystore.csv")

# %%
df
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
df.tail()
# Out:
#                                                  App             Category  \
# 10836                               Sya9a Maroc - FR               FAMILY
# 10837               Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                         Parkinson Exercices FR              MEDICAL
# 10839                  The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840  iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        Rating Reviews                Size     Installs  Type Price  \
# 10836     4.5      38                 53M       5,000+  Free     0
# 10837     5.0       4                3.6M         100+  Free     0
# 10838     NaN       3                9.5M       1,000+  Free     0
# 10839     4.5     114  Varies with device       1,000+  Free     0
# 10840     4.5  398307                 19M  10,000,000+  Free     0
#
#       Content Rating             Genres      Last Updated         Current Ver  \
# ...

# %%
df.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='str')

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  str
#  1   Category        10841 non-null  str
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  str
#  4   Size            10841 non-null  str
#  5   Installs        10841 non-null  str
#  6   Type            10840 non-null  str
#  7   Price           10841 non-null  str
#  8   Content Rating  10840 non-null  str
#  9   Genres          10841 non-null  str
#  10  Last Updated    10841 non-null  str
#  11  Current Ver     10833 non-null  str
#  12  Android Ver     10838 non-null  str
# dtypes: float64(1), str(12)
# memory usage: 1.1 MB

# %%
df.describe()
# Out:
#             Rating
# count  9367.000000
# mean      4.193338
# std       0.537431
# min       1.000000
# 25%       4.000000
# 50%       4.300000
# 75%       4.500000
# max      19.000000

# %%
# Find the highest-rated apps
df[["Rating","App"]].sort_values(by=["Rating","App"],ascending=False).head()
# Out:
#        Rating                                      App
# 10472    19.0  Life Made WI-Fi Touchscreen Photo Frame
# 5482      5.0               meStudying: AP English Lit
# 7756      5.0                                  iReadMe
# 6030      5.0                            iCard BD Plus
# 9178      5.0                                  i am EB

# %%
df[["Rating","App"]].max()
# Out:
# Rating                                                19.0
# App       🔥 Football Wallpapers 4K | Full HD Backgrounds 😍
# dtype: object

# %%
# Which category has the most apps?
df["Category"].value_counts().head(1)
# Out:
# Category
# FAMILY    1972
# Name: count, dtype: int64

# %%
# Average rating by category
df.groupby("Category")["Rating"].mean()
# Out:
# Category
# 1.9                    19.000000
# ART_AND_DESIGN          4.358065
# AUTO_AND_VEHICLES       4.190411
# BEAUTY                  4.278571
# BOOKS_AND_REFERENCE     4.346067
# BUSINESS                4.121452
# COMICS                  4.155172
# COMMUNICATION           4.158537
# DATING                  3.970769
# EDUCATION               4.389032
# ENTERTAINMENT           4.126174
# EVENTS                  4.435556
# FAMILY                  4.192272
# FINANCE                 4.131889
# FOOD_AND_DRINK          4.166972
# GAME                    4.286326
# HEALTH_AND_FITNESS      4.277104
# HOUSE_AND_HOME          4.197368
# LIBRARIES_AND_DEMO      4.178462
# LIFESTYLE               4.094904
# MAPS_AND_NAVIGATION     4.051613
# MEDICAL                 4.189143
# NEWS_AND_MAGAZINES      4.132189
# PARENTING               4.300000
# PERSONALIZATION         4.335987
# PHOTOGRAPHY             4.192114
# PRODUCTIVITY            4.211396
# SHOPPING                4.259664
# ...

# %%
# Free vs paid app analysis
df["Type"].value_counts()
# Out:
# Type
# Free    10039
# Paid      800
# 0           1
# Name: count, dtype: int64

# %%
# Most reviewed apps
df[["Reviews","App"]].sort_values(by="Reviews" ,ascending=False).head(5)
# Out:
#      Reviews                                App
# 2989    9992             GollerCepte Live Score
# 4970     999       Ad Block REMOVER - NEED ROOT
# 2723    9975                SnipSnap Coupon App
# 2705    9975                SnipSnap Coupon App
# 3079    9971  US Open Tennis Championships 2018

# %%
# Data cleaning and EDA

# %%
df.shape
# Out:
# (10841, 13)

# %%
df.isnull().sum()
# Out:
# App                  0
# Category             0
# Rating            1474
# Reviews              0
# Size                 0
# Installs             0
# Type                 1
# Price                0
# Content Rating       1
# Genres               0
# Last Updated         0
# Current Ver          8
# Android Ver          3
# dtype: int64

# %%
df[df.duplicated()]
# Out:
#                                                    App      Category  Rating  \
# 229                       Quick PDF Scanner + OCR FREE      BUSINESS     4.2
# 236                                                Box      BUSINESS     4.2
# 239                                 Google My Business      BUSINESS     4.4
# 256                                ZOOM Cloud Meetings      BUSINESS     4.4
# 261                          join.me - Simple Meetings      BUSINESS     4.0
# ...                                                ...           ...     ...
# 8643                    Wunderlist: To-Do List & Tasks  PRODUCTIVITY     4.6
# 8654   TickTick: To Do List with Reminder, Day Planner  PRODUCTIVITY     4.6
# 8658                           ColorNote Notepad Notes  PRODUCTIVITY     4.6
# 10049        Airway Ex - Intubate. Anesthetize. Train.       MEDICAL     4.3
# 10768                                             AAFP       MEDICAL     3.8
#
# ...

# %%
df["Category"].unique()
# Out:
# <StringArray>
# [     'ART_AND_DESIGN',   'AUTO_AND_VEHICLES',              'BEAUTY',
#  'BOOKS_AND_REFERENCE',            'BUSINESS',              'COMICS',
#        'COMMUNICATION',              'DATING',           'EDUCATION',
#        'ENTERTAINMENT',              'EVENTS',             'FINANCE',
#       'FOOD_AND_DRINK',  'HEALTH_AND_FITNESS',      'HOUSE_AND_HOME',
#   'LIBRARIES_AND_DEMO',           'LIFESTYLE',                'GAME',
#               'FAMILY',             'MEDICAL',              'SOCIAL',
#             'SHOPPING',         'PHOTOGRAPHY',              'SPORTS',
#     'TRAVEL_AND_LOCAL',               'TOOLS',     'PERSONALIZATION',
#         'PRODUCTIVITY',           'PARENTING',             'WEATHER',
#        'VIDEO_PLAYERS',  'NEWS_AND_MAGAZINES', 'MAPS_AND_NAVIGATION',
#                  '1.9']
# Length: 34, dtype: str

# %%
df["Category"].value_counts().head(1)
# Out:
# Category
# FAMILY    1972
# Name: count, dtype: int64

# %%
df["Rating"].mean()
# Out:
# np.float64(4.193338315362443)

# %%
df[df["Rating"]==df["Rating"].max()][["App","Rating"]]
# Out:
#                                            App  Rating
# 10472  Life Made WI-Fi Touchscreen Photo Frame    19.0

# %%
df[df["Rating"]==df["Rating"].min()][["App","Rating"]]
# Out:
#                                                     App  Rating
# 625                             House party - live chat     1.0
# 4127                                  Speech Therapy: F     1.0
# 5151                                      Clarksburg AH     1.0
# 5978                      Truck Driving Test Class 3 BC     1.0
# 6319                   BJ Bridge Standard American 2018     1.0
# 6490                                             MbH BM     1.0
# 7144                                      CB Mobile Biz     1.0
# 7383                                     Thistletown CI     1.0
# 7427                                     CJ DVD Rentals     1.0
# 7806                                        CR Magazine     1.0
# 7926                               Tech CU Card Manager     1.0
# 8820                                     DS Creator 2.0     1.0
# 8875                                     DT future1 cam     1.0
# 10324                    FE Mechanical Engineering Prep     1.0
# ...

# %%
df["Rating"].value_counts().sort_index()
# Out:
# Rating
# 1.0       16
# 1.2        1
# 1.4        3
# 1.5        3
# 1.6        4
# 1.7        8
# 1.8        8
# 1.9       13
# 2.0       12
# 2.1        8
# 2.2       14
# 2.3       20
# 2.4       19
# 2.5       21
# 2.6       25
# 2.7       25
# 2.8       42
# 2.9       45
# 3.0       83
# 3.1       69
# 3.2       64
# 3.3      102
# 3.4      128
# 3.5      163
# 3.6      174
# 3.7      239
# 3.8      303
# 3.9      386
# 4.0      568
# 4.1      708
# 4.2      952
# 4.3     1076
# 4.4     1109
# 4.5     1038
# 4.6      823
# 4.7      499
# 4.8      234
# 4.9       87
# 5.0      274
# 19.0       1
# Name: count, dtype: int64

# %%
# most reviewed apps
df["Reviews"]=pd.to_numeric(df["Reviews"]).nlargest(10,"Reviews")[["App","Reviews"]]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File pandas/_libs/lib.pyx:2478, in pandas._libs.lib.maybe_convert_numeric()
# -> 2478 'Could not get source, probably due dynamically evaluated source code.'
#
# ValueError: Unable to parse string "3.0M"
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[26], line 2
#       1 # most reviewed apps
# ----> 2 df["Reviews"]=pd.to_numeric(df["Reviews"]).nlargest(10,"Reviews")[["App","Reviews"]]
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\tools\numeric.py:235, in to_numeric(arg, errors, downcast, dtype_backend)
#     233     values = ensure_object(values)
#     234     coerce_numeric = errors != "raise"
# ...

# %%
df.sort_values("Size",ascending=False).head()
# Out:
#                                App            Category  Rating  Reviews  \
# 3675               VLC for Android       VIDEO_PLAYERS     4.4  1032076
# 9575    Red Hands – 2-Player Games                GAME     4.2    93608
# 5779  AW - Le News di AndroidWorld  NEWS_AND_MAGAZINES     4.1     2808
# 5778       ByssWeather for Wear OS             WEATHER     4.2    19666
# 5773               Bits Watch Face        PRODUCTIVITY     4.0     6205
#
#                     Size      Installs  Type Price Content Rating  \
# 3675  Varies with device  100,000,000+  Free     0       Everyone
# 9575  Varies with device   10,000,000+  Free     0       Everyone
# 5779  Varies with device      100,000+  Free     0       Everyone
# 5778  Varies with device    1,000,000+  Free     0       Everyone
# 5773  Varies with device      100,000+  Free     0       Everyone
#
#                        Genres      Last Updated         Current Ver  \
# ...

# %%
df["Size"]=df["Size"].str.replace("M","")
df["Size"]=df["Size"].str.replace("k","")
df["Size"]=pd.to_numeric(df["Size"],errors="coerce")
df.groupby("Category")["Size"].mean()
# Out:
# Category
# 1.9                           NaN
# ART_AND_DESIGN          12.370968
# AUTO_AND_VEHICLES       34.502667
# BEAUTY                  13.795745
# BOOKS_AND_REFERENCE     40.349746
# BUSINESS                26.622500
# COMICS                  34.111765
# COMMUNICATION           55.786792
# DATING                  16.710377
# EDUCATION               30.528829
# ENTERTAINMENT           21.853333
# EVENTS                  19.817544
# FAMILY                  38.007697
# FINANCE                 28.894788
# FOOD_AND_DRINK          22.185000
# GAME                    45.797241
# HEALTH_AND_FITNESS      38.178030
# HOUSE_AND_HOME          25.616176
# LIBRARIES_AND_DEMO     180.834146
# LIFESTYLE               31.265507
# MAPS_AND_NAVIGATION     31.312963
# MEDICAL                 44.495853
# NEWS_AND_MAGAZINES      14.448148
# PARENTING               22.512963
# PERSONALIZATION         42.655493
# PHOTOGRAPHY             21.249606
# PRODUCTIVITY            35.628713
# ...

# %%
# most installed apps
df["Installs"]=pd.to_numeric(df["Installs"],errors="coerce")
df.nlargest(10,"Installs")
# Out:
#                                                     App        Category  \
# 9148                          Command & Conquer: Rivals          FAMILY
# 0        Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN
# 1                                   Coloring book moana  ART_AND_DESIGN
# 2     U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN
# 3                                 Sketch - Draw & Paint  ART_AND_DESIGN
# 4                 Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN
# 5                            Paper flowers instructions  ART_AND_DESIGN
# 6               Smoke Effect Photo Maker - Smoke Editor  ART_AND_DESIGN
# 7                                      Infinite Painter  ART_AND_DESIGN
# 8                                  Garden Coloring Book  ART_AND_DESIGN
#
#       Rating Reviews  Size  Installs  Type Price Content Rating  \
# 9148     NaN       0   NaN       0.0   NaN     0   Everyone 10+
# ...

# %%
df["Installs"]=pd.to_numeric(df["Installs"])
df.dtypes
# Out:
# App                   str
# Category              str
# Rating            float64
# Reviews               str
# Size              float64
# Installs          float64
# Type                  str
# Price                 str
# Content Rating        str
# Genres                str
# Last Updated          str
# Current Ver           str
# Android Ver           str
# dtype: object

# %%
df.groupby("Category")["Installs"].mean().sort_values(ascending=False)
# Out:
# Category
# FAMILY                 0.0
# 1.9                    NaN
# ART_AND_DESIGN         NaN
# AUTO_AND_VEHICLES      NaN
# BEAUTY                 NaN
# BOOKS_AND_REFERENCE    NaN
# BUSINESS               NaN
# COMICS                 NaN
# COMMUNICATION          NaN
# DATING                 NaN
# EDUCATION              NaN
# ENTERTAINMENT          NaN
# EVENTS                 NaN
# FINANCE                NaN
# FOOD_AND_DRINK         NaN
# GAME                   NaN
# HEALTH_AND_FITNESS     NaN
# HOUSE_AND_HOME         NaN
# LIBRARIES_AND_DEMO     NaN
# LIFESTYLE              NaN
# MAPS_AND_NAVIGATION    NaN
# MEDICAL                NaN
# NEWS_AND_MAGAZINES     NaN
# PARENTING              NaN
# PERSONALIZATION        NaN
# PHOTOGRAPHY            NaN
# PRODUCTIVITY           NaN
# SHOPPING               NaN
# SOCIAL                 NaN
# SPORTS                 NaN
# TOOLS                  NaN
# TRAVEL_AND_LOCAL       NaN
# VIDEO_PLAYERS          NaN
# WEATHER                NaN
# ...

# %%
df.dropna().sum()
# Out:
# App
# Category
# Rating            0.0
# Reviews
# Size              0.0
# Installs          0.0
# Type
# Price
# Content Rating
# Genres
# Last Updated
# Current Ver
# Android Ver
# dtype: object

# %%
df.groupby("Category")["Installs"].mean().sort_values(ascending=False)
# Out:
# Category
# FAMILY                 0.0
# 1.9                    NaN
# ART_AND_DESIGN         NaN
# AUTO_AND_VEHICLES      NaN
# BEAUTY                 NaN
# BOOKS_AND_REFERENCE    NaN
# BUSINESS               NaN
# COMICS                 NaN
# COMMUNICATION          NaN
# DATING                 NaN
# EDUCATION              NaN
# ENTERTAINMENT          NaN
# EVENTS                 NaN
# FINANCE                NaN
# FOOD_AND_DRINK         NaN
# GAME                   NaN
# HEALTH_AND_FITNESS     NaN
# HOUSE_AND_HOME         NaN
# LIBRARIES_AND_DEMO     NaN
# LIFESTYLE              NaN
# MAPS_AND_NAVIGATION    NaN
# MEDICAL                NaN
# NEWS_AND_MAGAZINES     NaN
# PARENTING              NaN
# PERSONALIZATION        NaN
# PHOTOGRAPHY            NaN
# PRODUCTIVITY           NaN
# SHOPPING               NaN
# SOCIAL                 NaN
# SPORTS                 NaN
# TOOLS                  NaN
# TRAVEL_AND_LOCAL       NaN
# VIDEO_PLAYERS          NaN
# WEATHER                NaN
# ...

# %%
df.describe(include='all')
# Out:
#            App Category       Rating Reviews         Size  Installs   Type  \
# count    10841    10841  9367.000000   10841  9145.000000       1.0  10840
# unique    9660       34          NaN    6002          NaN       NaN      3
# top     ROBLOX   FAMILY          NaN       0          NaN       NaN   Free
# freq         9     1972          NaN     596          NaN       NaN  10039
# mean       NaN      NaN     4.193338     NaN    37.035440       0.0    NaN
# std        NaN      NaN     0.537431     NaN    98.873769       NaN    NaN
# min        NaN      NaN     1.000000     NaN     1.000000       0.0    NaN
# 25%        NaN      NaN     4.000000     NaN     5.600000       0.0    NaN
# 50%        NaN      NaN     4.300000     NaN    15.000000       0.0    NaN
# 75%        NaN      NaN     4.500000     NaN    34.000000       0.0    NaN
# max        NaN      NaN    19.000000     NaN  1020.000000       0.0    NaN
#
# ...

# %%
# count numerical and categorical columns
num_cols=df.select_dtypes(include='number').columns
print(num_cols)
cat_cols=df.select_dtypes(include="object").columns
print(cat_cols)
# Out:
# Index(['Rating', 'Size', 'Installs'], dtype='str')
# Index(['App', 'Category', 'Reviews', 'Type', 'Price', 'Content Rating',
#        'Genres', 'Last Updated', 'Current Ver', 'Android Ver'],
#       dtype='str')
# C:\Users\sahil\AppData\Local\Temp\ipykernel_15732\2400069286.py:4: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   cat_cols=df.select_dtypes(include="object").columns

# %%
# univarient
# 1.distribution of app ratings
# 2. distribution of reviews
# 3. category distribution
# 4. type (free - paid ) distribution
# 5. top 15 categories

# %%
# bivarient 
# 1. Avg rating by category and plot the chart 
avg_rating = df.groupby("Category")["Rating"].mean().sort_values()
avg_rating
# Out:
# Category
# DATING                  3.970769
# TOOLS                   4.047411
# MAPS_AND_NAVIGATION     4.051613
# VIDEO_PLAYERS           4.063750
# LIFESTYLE               4.094904
# TRAVEL_AND_LOCAL        4.109292
# BUSINESS                4.121452
# ENTERTAINMENT           4.126174
# FINANCE                 4.131889
# NEWS_AND_MAGAZINES      4.132189
# COMICS                  4.155172
# COMMUNICATION           4.158537
# FOOD_AND_DRINK          4.166972
# LIBRARIES_AND_DEMO      4.178462
# MEDICAL                 4.189143
# AUTO_AND_VEHICLES       4.190411
# PHOTOGRAPHY             4.192114
# FAMILY                  4.192272
# HOUSE_AND_HOME          4.197368
# PRODUCTIVITY            4.211396
# SPORTS                  4.223511
# WEATHER                 4.244000
# SOCIAL                  4.255598
# SHOPPING                4.259664
# HEALTH_AND_FITNESS      4.277104
# BEAUTY                  4.278571
# GAME                    4.286326
# PARENTING               4.300000
# ...

# %%
# free paid rating distribution
# rating vs reviews
# rating vs size
# installs by category
# average price by category
# reviews vs installs

# %%
# check missing values
df.isnull().sum()
# Out:
# App                   0
# Category              0
# Rating             1474
# Reviews               0
# Size               1696
# Installs          10840
# Type                  1
# Price                 0
# Content Rating        1
# Genres                0
# Last Updated          0
# Current Ver           8
# Android Ver           3
# dtype: int64

# %%
df[df.duplicated()]
# Out:
#                                                    App      Category  Rating  \
# 229                       Quick PDF Scanner + OCR FREE      BUSINESS     4.2
# 236                                                Box      BUSINESS     4.2
# 239                                 Google My Business      BUSINESS     4.4
# 256                                ZOOM Cloud Meetings      BUSINESS     4.4
# 261                          join.me - Simple Meetings      BUSINESS     4.0
# ...                                                ...           ...     ...
# 8643                    Wunderlist: To-Do List & Tasks  PRODUCTIVITY     4.6
# 8654   TickTick: To Do List with Reminder, Day Planner  PRODUCTIVITY     4.6
# 8658                           ColorNote Notepad Notes  PRODUCTIVITY     4.6
# 10049        Airway Ex - Intubate. Anesthetize. Train.       MEDICAL     4.3
# 10768                                             AAFP       MEDICAL     3.8
#
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(483)

# %%
# remove duplicate records
df.drop_duplicates(inplace=True)

# %%
# step 1: inspect the column installs 
df["Installs"].head()
# Out:
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
# Name: Installs, dtype: float64
