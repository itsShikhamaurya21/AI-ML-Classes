# %%
import pandas as pd

# %%
import numpy as np

# %%
df=pd.read_csv("students.csv")

# %%
df
# Out:
#    StudentID    Name  Age  Gender  Course  Marks           City
# 0        101  Shikha   22  Female  Python     85          Noida
# 1        102   Sahil   21    Male    Java     78          Delhi
# 2        103  Shital   32  Female  Python     92      Ghaziabad
# 3        104   Rohan   23    Male     C++     67          Noida
# 4        105   Priya   24  Female    Java     88          Delhi
# 5        106    Amit   22    Male  Python     75  Greater Noida
# 6        107    Neha   23  Female     C++     81      Ghaziabad
# 7        108     Raj   25    Male    Java     69          Delhi
# 8        109  Anjali   21  Female  Python     95          Noida
# 9        110   Vikas   24    Male     C++     72  Greater Noida

# %%
df.head()
# Out:
#    StudentID    Name  Age  Gender  Course  Marks       City
# 0        101  Shikha   22  Female  Python     85      Noida
# 1        102   Sahil   21    Male    Java     78      Delhi
# 2        103  Shital   32  Female  Python     92  Ghaziabad
# 3        104   Rohan   23    Male     C++     67      Noida
# 4        105   Priya   24  Female    Java     88      Delhi

# %%
df.head(10)
# Out:
#    StudentID    Name  Age  Gender  Course  Marks           City
# 0        101  Shikha   22  Female  Python     85          Noida
# 1        102   Sahil   21    Male    Java     78          Delhi
# 2        103  Shital   32  Female  Python     92      Ghaziabad
# 3        104   Rohan   23    Male     C++     67          Noida
# 4        105   Priya   24  Female    Java     88          Delhi
# 5        106    Amit   22    Male  Python     75  Greater Noida
# 6        107    Neha   23  Female     C++     81      Ghaziabad
# 7        108     Raj   25    Male    Java     69          Delhi
# 8        109  Anjali   21  Female  Python     95          Noida
# 9        110   Vikas   24    Male     C++     72  Greater Noida

# %%
df.tail()
# Out:
#    StudentID    Name  Age  Gender  Course  Marks           City
# 5        106    Amit   22    Male  Python     75  Greater Noida
# 6        107    Neha   23  Female     C++     81      Ghaziabad
# 7        108     Raj   25    Male    Java     69          Delhi
# 8        109  Anjali   21  Female  Python     95          Noida
# 9        110   Vikas   24    Male     C++     72  Greater Noida

# %%
df.tail()
# Out:
#    StudentID    Name  Age  Gender  Course  Marks           City
# 5        106    Amit   22    Male  Python     75  Greater Noida
# 6        107    Neha   23  Female     C++     81      Ghaziabad
# 7        108     Raj   25    Male    Java     69          Delhi
# 8        109  Anjali   21  Female  Python     95          Noida
# 9        110   Vikas   24    Male     C++     72  Greater Noida

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   StudentID  10 non-null     int64
#  1   Name       10 non-null     str
#  2   Age        10 non-null     int64
#  3   Gender     10 non-null     str
#  4   Course     10 non-null     str
#  5   Marks      10 non-null     int64
#  6   City       10 non-null     str
# dtypes: int64(3), str(4)
# memory usage: 692.0 bytes

# %%
df.describe()
# Out:
#        StudentID        Age      Marks
# count   10.00000  10.000000  10.000000
# mean   105.50000  23.700000  80.200000
# std      3.02765   3.198958   9.670114
# min    101.00000  21.000000  67.000000
# 25%    103.25000  22.000000  72.750000
# 50%    105.50000  23.000000  79.500000
# 75%    107.75000  24.000000  87.250000
# max    110.00000  32.000000  95.000000

# %%
df.columns
# Out:
# Index(['StudentID', 'Name', 'Age', 'Gender', 'Course', 'Marks', 'City'], dtype='str')

# %%
df.size
# Out:
# 70

# %%
df.shape
# Out:
# (10, 7)

# %%
df.sample()
# Out:
#    StudentID  Name  Age Gender  Course  Marks           City
# 5        106  Amit   22   Male  Python     75  Greater Noida

# %%
df.dtypes
# Out:
# StudentID    int64
# Name           str
# Age          int64
# Gender         str
# Course         str
# Marks        int64
# City           str
# dtype: object

# %%
df.isnull()
# Out:
#    StudentID   Name    Age  Gender  Course  Marks   City
# 0      False  False  False   False   False  False  False
# 1      False  False  False   False   False  False  False
# 2      False  False  False   False   False  False  False
# 3      False  False  False   False   False  False  False
# 4      False  False  False   False   False  False  False
# 5      False  False  False   False   False  False  False
# 6      False  False  False   False   False  False  False
# 7      False  False  False   False   False  False  False
# 8      False  False  False   False   False  False  False
# 9      False  False  False   False   False  False  False

# %%
df.isnull().sum()
# Out:
# StudentID    0
# Name         0
# Age          0
# Gender       0
# Course       0
# Marks        0
# City         0
# dtype: int64

# %%
df.isnotnull().sum()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 df.isnotnull().sum()
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\generic.py:6206, in NDFrame.__getattr__(self, name)
#    6202             and name not in self._accessors
#    6203             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6204         ):
#    6205             return self[name]
# -> 6206         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'isnotnull'

# %%
print(df["Name"])
# Out:
# 0    Shikha
# 1     Sahil
# 2    Shital
# 3     Rohan
# 4     Priya
# 5      Amit
# 6      Neha
# 7       Raj
# 8    Anjali
# 9     Vikas
# Name: Name, dtype: str

# %%
print(df[["Name","Age"]])
# Out:
#      Name  Age
# 0  Shikha   22
# 1   Sahil   21
# 2  Shital   32
# 3   Rohan   23
# 4   Priya   24
# 5    Amit   22
# 6    Neha   23
# 7     Raj   25
# 8  Anjali   21
# 9   Vikas   24

# %%
print(df[["Name","Age","Gender"]])
# Out:
#      Name  Age  Gender
# 0  Shikha   22  Female
# 1   Sahil   21    Male
# 2  Shital   32  Female
# 3   Rohan   23    Male
# 4   Priya   24  Female
# 5    Amit   22    Male
# 6    Neha   23  Female
# 7     Raj   25    Male
# 8  Anjali   21  Female
# 9   Vikas   24    Male

# %%
print(df[df["Marks"]>75])
# Out:
#    StudentID    Name  Age  Gender  Course  Marks       City
# 0        101  Shikha   22  Female  Python     85      Noida
# 1        102   Sahil   21    Male    Java     78      Delhi
# 2        103  Shital   32  Female  Python     92  Ghaziabad
# 4        105   Priya   24  Female    Java     88      Delhi
# 6        107    Neha   23  Female     C++     81  Ghaziabad
# 8        109  Anjali   21  Female  Python     95      Noida

# %%
df=df.set_index("StudentID")

# %%
df
# Out:
#              Name  Age  Gender  Course  Marks           City
# StudentID
# 101        Shikha   22  Female  Python     85          Noida
# 102         Sahil   21    Male    Java     78          Delhi
# 103        Shital   32  Female  Python     92      Ghaziabad
# 104         Rohan   23    Male     C++     67          Noida
# 105         Priya   24  Female    Java     88          Delhi
# 106          Amit   22    Male  Python     75  Greater Noida
# 107          Neha   23  Female     C++     81      Ghaziabad
# 108           Raj   25    Male    Java     69          Delhi
# 109        Anjali   21  Female  Python     95          Noida
# 110         Vikas   24    Male     C++     72  Greater Noida

# %%
df.dropna()
# Out:
#              Name  Age  Gender  Course  Marks           City
# StudentID
# 101        Shikha   22  Female  Python     85          Noida
# 102         Sahil   21    Male    Java     78          Delhi
# 103        Shital   32  Female  Python     92      Ghaziabad
# 104         Rohan   23    Male     C++     67          Noida
# 105         Priya   24  Female    Java     88          Delhi
# 106          Amit   22    Male  Python     75  Greater Noida
# 107          Neha   23  Female     C++     81      Ghaziabad
# 108           Raj   25    Male    Java     69          Delhi
# 109        Anjali   21  Female  Python     95          Noida
# 110         Vikas   24    Male     C++     72  Greater Noida

# %%
df.dropna(axis=0)
# Out:
#              Name  Age  Gender  Course  Marks           City
# StudentID
# 101        Shikha   22  Female  Python     85          Noida
# 102         Sahil   21    Male    Java     78          Delhi
# 103        Shital   32  Female  Python     92      Ghaziabad
# 104         Rohan   23    Male     C++     67          Noida
# 105         Priya   24  Female    Java     88          Delhi
# 106          Amit   22    Male  Python     75  Greater Noida
# 107          Neha   23  Female     C++     81      Ghaziabad
# 108           Raj   25    Male    Java     69          Delhi
# 109        Anjali   21  Female  Python     95          Noida
# 110         Vikas   24    Male     C++     72  Greater Noida
